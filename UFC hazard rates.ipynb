# %%
import pandas as pd
from transform import *

# %%
totals, sig_strikes, fight_details = extract()

# %%
sig_strikes = transform_sig_stikes(sig_strikes)

# %%
fight_details['round'] = fight_details['round'].apply(lambda x: x.split(":")[1]).astype(int)
fight_details['last_round_secs'] = fight_details['time'].apply(lambda x: int(x.split(":")[1])*60 + int(x.split(":")[2]))
fight_details['fight_time'] = fight_details.apply(lambda x: (x['round'] -1)*300 + x['last_round_secs'], axis = 1)

# %%
strikes_by_fight = sig_strikes.groupby(['url','name']).sum().reset_index()
strikes_by_fight.head()
# Out:
#                                                  url              name  \
# 0  http://www.fightmetric.com/fight-details/000da...         Josh Neer
# 1  http://www.fightmetric.com/fight-details/000da...    Joshua Burkman
# 2  http://www.fightmetric.com/fight-details/0027e...     Jared Rosholt
# 3  http://www.fightmetric.com/fight-details/0027e...     Josh Copeland
# 4  http://www.fightmetric.com/fight-details/00292...  Alistair Overeem
#
#    body_strikes  body_attempts  ground_strikes  ground_attempts  head_strikes  \
# 0             1              2               7                9            17
# 1             9             12               5               10            22
# 2             3              4              10               17            19
# 3             2              2               0                0             7
# 4             5              6              14               20            12
#
#    head_attempts  leg_strikes  leg_attempts  distance_strikes  \
# 0             36            1             1                 7
# 1             72            4             4                14
# 2             41            0             0                 9
# 3             34            0             0                 6
# 4             18            0             1                 0
#
#    distance_attempts  clinch_strikes  clich_attempts
# 0                 21               5               9
# 1                 50              16              28
# 2                 24               3               4
# 3                 28               3               8
# 4                  2               3               3

# %%
surv_df = pd.merge(fight_details, strikes_by_fight, on = 'url', how = 'left')
surv_df['KO'] = surv_df.apply(lambda x: x['name'] == x['winner'] and x['method']=="KO/TKO", axis = 1)

# %%
surv_df[surv_df['KO']][['name','bout','winner','loser','head_strikes']].head()
# Out:
#                name                                               bout  \
# 1        Tito Ortiz                             Light Heavyweight Bout
# 3     Kendall Grove                                  Middleweight Bout
# 19       Roy Nelson  Ultimate Fighter 10 Heavyweight Tournament Tit...
# 27    Matt Mitrione                                   Heavyweight Bout
# 29  James McSweeney                                   Heavyweight Bout
#
#              winner               loser  head_strikes
# 1        Tito Ortiz        Ken Shamrock            15
# 3     Kendall Grove         Chris Price            12
# 19       Roy Nelson      Brendan Schaub             8
# 27    Matt Mitrione        Marcus Jones             6
# 29  James McSweeney  Darrill Schoonover            40

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/stephenma/anaconda2/lib/python2.7/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['extract', 'datetime']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
surv_df_3 = surv_df[surv_df['time_format'] == 'Timeformat:3Rnd(5-5-5)']

# %%
surv_df_3[surv_df_3['KO']]['fight_time'].plot(kind = 'hist', figsize = [20,5], bins = 50, 
                                              title = "Distribution of total fight times (3 Rounds)")
print surv_df_3[surv_df_3['KO']]['fight_time'].describe()
# Out:
# count    1135.000000
# mean      319.928634
# std       231.763227
# min         7.000000
# 25%       127.000000
# 50%       274.000000
# 75%       476.500000
# max       898.000000
# Name: fight_time, dtype: float64

# %%
from lifelines import KaplanMeierFitter
kmf = KaplanMeierFitter()

kmf.fit(surv_df_3['fight_time'], event_observed=surv_df_3['KO'])
kmf.plot(title = "Probability of Surviving (a KO)", figsize = [15,7])

# %%
survival_func = kmf.survival_function_
shifted_survival_diff = (1 - survival_func/survival_func. shift(1))
hazard_empirical = shifted_survival_diff.div(survival_func.index.to_series(), axis=0)

hazard_empirical.columns = ['hazard rate']

ax = hazard_empirical.plot(title = "Hazard Rate (apprx.)",figsize = [15,7])

_ = ax.annotate('End of 1st Round', xy=(299, hazard.ix[299]*1.1), xytext=(300, hazard.ix[299]*1.5),
            arrowprops=dict(facecolor='black', shrink=0.005))

# %%
hazard_empirical.ix[250:300]
# Out:
# /Users/stephenma/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#            hazard rate
# timeline
# 250.0     4.123711e-06
# 251.0     6.861977e-07
# 252.0     0.000000e+00
# 253.0     3.406213e-06
# 254.0     6.799668e-07
# 255.0     2.712011e-06
# 256.0     6.772278e-07
# 257.0     6.752951e-07
# 258.0     2.692580e-06
# 259.0     0.000000e+00
# 260.0     2.009485e-06
# 261.0     2.004578e-06
# 262.0     1.335010e-06
# 263.0     1.331797e-06
# 264.0     2.656296e-06
# 265.0     6.624974e-07
# 267.0     1.315532e-06
# 268.0     1.970780e-06
# 269.0     1.310353e-06
# 270.0     6.536717e-07
# 271.0     6.526418e-07
# 272.0     1.952800e-06
# 273.0     6.494687e-07
# 274.0     1.296496e-06
# 275.0     1.293619e-06
# 276.0     1.291229e-06
# 277.0     1.931917e-06
# 278.0     2.570291e-06
# 279.0     1.283750e-06
# 280.0     3.200205e-06
# 281.0     1.278275e-06
# 282.0     1.912675e-06
# 283.0     1.272899e-06
# 284.0     1.905372e-06
# 285.0     2.535240e-06
# 286.0     0.000000e+00
# 287.0     6.309889e-07
# 288.0     1.258052e-06
# 289.0     1.255063e-06
# 290.0     1.878146e-06
# 291.0     1.249155e-06
# 292.0     1.869355e-06
# 293.0     6.216702e-07
# 294.0     1.240920e-06
# 295.0     2.477041e-06
# 296.0     1.236595e-06
# 297.0     4.933338e-06
# 298.0     1.234169e-06
# 299.0     6.156999e-06
# 300.0     4.316192e-06
